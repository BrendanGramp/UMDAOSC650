# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendanGramp/UMDAOSC650/blob/main/autoencodermodified2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import keras
from keras import layers

# %%
# Set the seed using keras.utils.set_random_seed. This will set:
# 1) `numpy` seed
# 2) backend random seed
# 3) `python` random seed
keras.utils.set_random_seed(812)

# %%
! wget https://zenodo.org/records/10576726/files/current_SP3hourly_20110427.nc
# Out:
# --2024-04-09 16:34:34--  https://zenodo.org/records/10576726/files/current_SP3hourly_20110427.nc
# Resolving zenodo.org (zenodo.org)... 188.184.103.159, 188.184.98.238, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109400556 (104M) [application/octet-stream]
# Saving to: ‘current_SP3hourly_20110427.nc’
#
# current_SP3hourly_2 100%[===================>] 104.33M  1.61MB/s    in 68s
#
# 2024-04-09 16:35:43 (1.53 MB/s) - ‘current_SP3hourly_20110427.nc’ saved [109400556/109400556]

# %%
# import dataset (netcdf)
ds = xr.open_dataset('current_SP3hourly_20110427.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (starttime: 2224, y: 32, x: 32)
# Coordinates:
#   * starttime    (starttime) float64 9.264e+04 9.264e+04 ... 9.266e+04 9.266e+04
#     endtime      (starttime) float64 ...
#     x_speed      (starttime) int64 ...
#     y_speed      (starttime) int64 ...
# Dimensions without coordinates: y, x
# Data variables:
#     uh25_grid    (starttime, y, x) float32 ...
#     uh03_grid    (starttime, y, x) float32 ...
#     ctt_grid     (starttime, y, x) float32 ...
#     dbz_grid     (starttime, y, x) float32 ...
#     mask         (starttime, y, x) int64 ...
#     row_indices  (starttime, y, x) int64 ...
#     col_indices  (starttime, y, x) int64 ...
#     lats         (starttime, y, x) float32 ...
#     lons         (starttime, y, x) float32 ...

# %% [markdown]
# ## ANN Autoencoder

# %% [markdown]
# We will again use the previous data, but this time we will focus on reconstructing one input variable (feature).

# %%
# selecting a variable
ds['dbz_grid']
# Out:
# <xarray.DataArray 'dbz_grid' (starttime: 2224, y: 32, x: 32)>
# [2277376 values with dtype=float32]
# Coordinates:
#   * starttime  (starttime) float64 9.264e+04 9.264e+04 ... 9.266e+04 9.266e+04
#     endtime    (starttime) float64 ...
#     x_speed    (starttime) int64 ...
#     y_speed    (starttime) int64 ...
# Dimensions without coordinates: y, x

# %%
# reshape data to be samples, features
features_data = ds['dbz_grid'].stack(new_dim=(["y", "x"])).values
print(features_data.shape)
# Out:
# (2224, 1024)

# %%
features_data
# Out:
# array([[-35.      , -35.      , -35.      , ...,  13.949479,  12.911252,
#          10.474219],
#        [-35.      , -35.      , -35.      , ...,  15.252525,   9.551773,
#         -12.005707],
#        [-35.      , -35.      , -35.      , ..., -35.      , -35.      ,
#         -35.      ],
#        ...,
#        [-29.150763, -33.773006, -35.      , ..., -12.28549 , -21.292902,
#         -30.720982],
#        [ 24.57368 ,  13.765106,  14.084679, ...,  29.180717,  28.653072,
#          28.988672],
#        [ 13.142024,  16.35466 ,  17.247124, ...,  25.714262,  23.523518,
#          26.171114]], dtype=float32)

# %%
# split dataset into training and testing set
X_train, X_test, y_train, y_test = train_test_split(
    features_data,
    features_data,
    test_size=0.3,
    shuffle=False,
    random_state=42)

# %%
# now rescale your data
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train) # input
X_test = scaler.transform(X_test) # input
y_train = scaler.transform(y_train) # label
y_test = scaler.transform(y_test) # label

# %%
# check shapes
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1556, 1024) (668, 1024) (1556, 1024) (668, 1024)

# %%
# create fully connected autoencoder
model = keras.Sequential()

# input
model.add(keras.Input(shape=(1024))) # features

# encoder
# hidden layers
model.add(layers.Dense(32, activation="relu"))
model.add(layers.Dense(8, activation="relu"))

# desired dimensions
model.add(layers.Dense(4, activation="relu"))

# decoder
model.add(layers.Dense(8, activation="relu"))
model.add(layers.Dense(32, activation="relu"))

# Finally, we add last layer
model.add(layers.Dense(1024, activation='linear')) # back to the original shape

# print model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 32)                32800
#
#  dense_7 (Dense)             (None, 8)                 264
#
#  dense_8 (Dense)             (None, 4)                 36
#
#  dense_9 (Dense)             (None, 8)                 40
#
#  dense_10 (Dense)            (None, 32)                288
#
#  dense_11 (Dense)            (None, 1024)              33792
#
# =================================================================
# Total params: 67220 (262.58 KB)
# Trainable params: 67220 (262.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# define list of metrics
METRICS = [
    keras.metrics.MeanSquaredError(name='mean_squared_error'),
    keras.metrics.RootMeanSquaredError(name='root_mean_squared_error'),
    keras.metrics.MeanAbsoluteError(name='mean_absolute_error'),
    keras.metrics.MeanAbsolutePercentageError(name='mean_absolute_percentage_error'),
    keras.metrics.R2Score()
]

# compile your nn
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mean_squared_error",
    metrics=METRICS
)

# set hyperparameters
BATCH_SIZE = 32
EPOCHS = 50

# %%
# train the NN now
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,
    shuffle=True,
)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 6s 31ms/step - loss: 0.8038 - mean_squared_error: 0.8038 - root_mean_squared_error: 0.8966 - mean_absolute_error: 0.7135 - mean_absolute_percentage_error: 1452.4873 - r2_score: 0.1908 - val_loss: 0.6727 - val_mean_squared_error: 0.6727 - val_root_mean_squared_error: 0.8202 - val_mean_absolute_error: 0.6562 - val_mean_absolute_percentage_error: 293.2098 - val_r2_score: 0.3559
# Epoch 2/50
# 44/44 [==============================] - 1s 12ms/step - loss: 0.5503 - mean_squared_error: 0.5503 - root_mean_squared_error: 0.7418 - mean_absolute_error: 0.5572 - mean_absolute_percentage_error: 1752.6810 - r2_score: 0.4456 - val_loss: 0.5822 - val_mean_squared_error: 0.5822 - val_root_mean_squared_error: 0.7630 - val_mean_absolute_error: 0.5882 - val_mean_absolute_percentage_error: 373.6329 - val_r2_score: 0.4457
# Epoch 3/50
# 44/44 [==============================] - 1s 14ms/step - loss: 0.4919 - mean_squared_error: 0.4919 - root_mean_squared_error: 0.7013 - mean_absolute_error: 0.5187 - mean_absolute_percentage_error: 1064.7892 - r2_score: 0.5041 - val_loss: 0.5541 - val_mean_squared_error: 0.5541 - val_root_mean_squared_error: 0.7444 - val_mean_absolute_error: 0.5668 - val_mean_absolute_percentage_error: 339.0057 - val_r2_score: 0.4751
# Epoch 4/50
# 44/44 [==============================] - 1s 13ms/step - loss: 0.4648 - mean_squared_error: 0.4648 - root_mean_squared_error: 0.6818 - mean_absolute_error: 0.4987 - mean_absolute_percentage_error: 1557.6130 - r2_score: 0.5311 - val_loss: 0.5399 - val_mean_squared_error: 0.5399 - val_root_mean_squared_error: 0.7348 - val_mean_absolute_error: 0.5545 - val_mean_absolute_percentage_error: 367.5035 - val_r2_score: 0.4896
# Epoch 5/50
# 44/44 [==============================] - 1s 16ms/step - loss: 0.4556 - mean_squared_error: 0.4556 - root_mean_squared_error: 0.6750 - mean_absolute_error: 0.4896 - mean_absolute_percentage_error: 1501.5663 - r2_score: 0.5403 - val_loss: 0.5300 - val_mean_squared_error: 0.5300 - val_root_mean_squared_error: 0.7280 - val_mean_absolute_error: 0.5477 - val_mean_absolute_percentage_error: 374.5008 - val_r2_score: 0.4996
# Epoch 6/50
# 44/44 [==============================] - 0s 10ms/step - loss: 0.4505 - mean_squared_error: 0.4505 - root_mean_squared_error: 0.6712 - mean_absolute_error: 0.4853 - mean_absolute_percentage_error: 1443.8392 - r2_score: 0.5455 - val_loss: 0.5263 - val_mean_squared_error: 0.5263 - val_root_mean_squared_error: 0.7255 - val_mean_absolute_error: 0.5467 - val_mean_absolute_percentage_error: 378.5075 - val_r2_score: 0.5028
# Epoch 7/50
# 44/44 [==============================] - 0s 9ms/step - loss: 0.4485 - mean_squared_error: 0.4485 - root_mean_squared_error: 0.6697 - mean_absolute_error: 0.4836 - mean_absolute_percentage_error: 1325.3066 - r2_score: 0.5474 - val_loss: 0.5200 - val_mean_squared_error: 0.5200 - val_root_mean_squared_error: 0.7211 - val_mean_absolute_error: 0.5411 - val_mean_absolute_percentage_error: 363.5587 - val_r2_score: 0.5076
# Epoch 8/50
# 44/44 [==============================] - 0s 9ms/step - loss: 0.4446 - mean_squared_error: 0.4446 - root_mean_squared_error: 0.6668 - mean_absolute_error: 0.4810 - mean_absolute_percentage_error: 1309.3558 - r2_score: 0.5514 - val_loss: 0.5138 - val_mean_squared_error: 0.5138 - val_root_mean_squared_error: 0.7168 - val_mean_absolute_error: 0.5393 - val_mean_absolute_percentage_error: 362.2919 - val_r2_score: 0.5128
# Epoch 9/50
# 44/44 [==============================] - 0s 10ms/step - loss: 0.4383 - mean_squared_error: 0.4383 - root_mean_squared_error: 0.6620 - mean_absolute_error: 0.4780 - mean_absolute_percentage_error: 1458.4099 - r2_score: 0.5578 - val_loss: 0.4977 - val_mean_squared_error: 0.4977 - val_root_mean_squared_error: 0.7055 - val_mean_absolute_error: 0.5296 - val_mean_absolute_percentage_error: 355.9711 - val_r2_score: 0.5270
# Epoch 10/50
# 44/44 [==============================] - 0s 9ms/step - loss: 0.4194 - mean_squared_error: 0.4194 - root_mean_squared_error: 0.6476 - mean_absolute_error: 0.4687 - mean_absolute_percentage_error: 1194.7715 - r2_score: 0.5770 - val_loss: 0.4562 - val_mean_squared_error: 0.4562 - val_root_mean_squared_error: 0.6754 - val_mean_absolute_error: 0.5059 - val_mean_absolute_percentage_error: 358.3204 - val_r2_score: 0.5659
# Epoch 11/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.4004 - mean_squared_error: 0.4004 - root_mean_squared_error: 0.6328 - mean_absolute_error: 0.4573 - mean_absolute_percentage_error: 1463.4135 - r2_score: 0.5961 - val_loss: 0.4273 - val_mean_squared_error: 0.4273 - val_root_mean_squared_error: 0.6537 - val_mean_absolute_error: 0.4869 - val_mean_absolute_percentage_error: 362.8921 - val_r2_score: 0.5937
# Epoch 12/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3836 - mean_squared_error: 0.3836 - root_mean_squared_error: 0.6194 - mean_absolute_error: 0.4458 - mean_absolute_percentage_error: 1437.9861 - r2_score: 0.6131 - val_loss: 0.4027 - val_mean_squared_error: 0.4027 - val_root_mean_squared_error: 0.6345 - val_mean_absolute_error: 0.4690 - val_mean_absolute_percentage_error: 363.7306 - val_r2_score: 0.6161
# Epoch 13/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3746 - mean_squared_error: 0.3746 - root_mean_squared_error: 0.6120 - mean_absolute_error: 0.4388 - mean_absolute_percentage_error: 1353.5345 - r2_score: 0.6223 - val_loss: 0.3920 - val_mean_squared_error: 0.3920 - val_root_mean_squared_error: 0.6261 - val_mean_absolute_error: 0.4619 - val_mean_absolute_percentage_error: 341.3275 - val_r2_score: 0.6257
# Epoch 14/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3688 - mean_squared_error: 0.3688 - root_mean_squared_error: 0.6073 - mean_absolute_error: 0.4350 - mean_absolute_percentage_error: 1139.2068 - r2_score: 0.6281 - val_loss: 0.3820 - val_mean_squared_error: 0.3820 - val_root_mean_squared_error: 0.6181 - val_mean_absolute_error: 0.4554 - val_mean_absolute_percentage_error: 317.1075 - val_r2_score: 0.6354
# Epoch 15/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3668 - mean_squared_error: 0.3668 - root_mean_squared_error: 0.6057 - mean_absolute_error: 0.4330 - mean_absolute_percentage_error: 1487.2107 - r2_score: 0.6301 - val_loss: 0.3796 - val_mean_squared_error: 0.3796 - val_root_mean_squared_error: 0.6161 - val_mean_absolute_error: 0.4521 - val_mean_absolute_percentage_error: 331.4267 - val_r2_score: 0.6380
# Epoch 16/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3642 - mean_squared_error: 0.3642 - root_mean_squared_error: 0.6035 - mean_absolute_error: 0.4319 - mean_absolute_percentage_error: 1390.6442 - r2_score: 0.6327 - val_loss: 0.3755 - val_mean_squared_error: 0.3755 - val_root_mean_squared_error: 0.6128 - val_mean_absolute_error: 0.4502 - val_mean_absolute_percentage_error: 347.0076 - val_r2_score: 0.6410
# Epoch 17/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3612 - mean_squared_error: 0.3612 - root_mean_squared_error: 0.6010 - mean_absolute_error: 0.4296 - mean_absolute_percentage_error: 1195.7916 - r2_score: 0.6359 - val_loss: 0.3758 - val_mean_squared_error: 0.3758 - val_root_mean_squared_error: 0.6130 - val_mean_absolute_error: 0.4497 - val_mean_absolute_percentage_error: 342.8804 - val_r2_score: 0.6407
# Epoch 18/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3596 - mean_squared_error: 0.3596 - root_mean_squared_error: 0.5997 - mean_absolute_error: 0.4286 - mean_absolute_percentage_error: 1460.2904 - r2_score: 0.6374 - val_loss: 0.3746 - val_mean_squared_error: 0.3746 - val_root_mean_squared_error: 0.6120 - val_mean_absolute_error: 0.4482 - val_mean_absolute_percentage_error: 334.4282 - val_r2_score: 0.6418
# Epoch 19/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3585 - mean_squared_error: 0.3585 - root_mean_squared_error: 0.5987 - mean_absolute_error: 0.4276 - mean_absolute_percentage_error: 1239.6962 - r2_score: 0.6386 - val_loss: 0.3731 - val_mean_squared_error: 0.3731 - val_root_mean_squared_error: 0.6108 - val_mean_absolute_error: 0.4474 - val_mean_absolute_percentage_error: 334.8305 - val_r2_score: 0.6431
# Epoch 20/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3577 - mean_squared_error: 0.3577 - root_mean_squared_error: 0.5981 - mean_absolute_error: 0.4271 - mean_absolute_percentage_error: 1368.7661 - r2_score: 0.6393 - val_loss: 0.3733 - val_mean_squared_error: 0.3733 - val_root_mean_squared_error: 0.6110 - val_mean_absolute_error: 0.4467 - val_mean_absolute_percentage_error: 330.3598 - val_r2_score: 0.6433
# Epoch 21/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3566 - mean_squared_error: 0.3566 - root_mean_squared_error: 0.5971 - mean_absolute_error: 0.4264 - mean_absolute_percentage_error: 1291.2457 - r2_score: 0.6405 - val_loss: 0.3725 - val_mean_squared_error: 0.3725 - val_root_mean_squared_error: 0.6103 - val_mean_absolute_error: 0.4466 - val_mean_absolute_percentage_error: 330.0425 - val_r2_score: 0.6441
# Epoch 22/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3562 - mean_squared_error: 0.3562 - root_mean_squared_error: 0.5968 - mean_absolute_error: 0.4261 - mean_absolute_percentage_error: 1205.7397 - r2_score: 0.6409 - val_loss: 0.3716 - val_mean_squared_error: 0.3716 - val_root_mean_squared_error: 0.6096 - val_mean_absolute_error: 0.4459 - val_mean_absolute_percentage_error: 324.5832 - val_r2_score: 0.6448
# Epoch 23/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3548 - mean_squared_error: 0.3548 - root_mean_squared_error: 0.5957 - mean_absolute_error: 0.4252 - mean_absolute_percentage_error: 1280.3743 - r2_score: 0.6422 - val_loss: 0.3720 - val_mean_squared_error: 0.3720 - val_root_mean_squared_error: 0.6099 - val_mean_absolute_error: 0.4459 - val_mean_absolute_percentage_error: 335.5073 - val_r2_score: 0.6443
# Epoch 24/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3545 - mean_squared_error: 0.3545 - root_mean_squared_error: 0.5954 - mean_absolute_error: 0.4250 - mean_absolute_percentage_error: 1291.4491 - r2_score: 0.6426 - val_loss: 0.3731 - val_mean_squared_error: 0.3731 - val_root_mean_squared_error: 0.6108 - val_mean_absolute_error: 0.4465 - val_mean_absolute_percentage_error: 340.4568 - val_r2_score: 0.6425
# Epoch 25/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3535 - mean_squared_error: 0.3535 - root_mean_squared_error: 0.5945 - mean_absolute_error: 0.4243 - mean_absolute_percentage_error: 1172.2338 - r2_score: 0.6436 - val_loss: 0.3713 - val_mean_squared_error: 0.3713 - val_root_mean_squared_error: 0.6094 - val_mean_absolute_error: 0.4452 - val_mean_absolute_percentage_error: 347.3269 - val_r2_score: 0.6446
# Epoch 26/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3539 - mean_squared_error: 0.3539 - root_mean_squared_error: 0.5949 - mean_absolute_error: 0.4247 - mean_absolute_percentage_error: 1116.5134 - r2_score: 0.6432 - val_loss: 0.3725 - val_mean_squared_error: 0.3725 - val_root_mean_squared_error: 0.6103 - val_mean_absolute_error: 0.4467 - val_mean_absolute_percentage_error: 340.9958 - val_r2_score: 0.6435
# Epoch 27/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3526 - mean_squared_error: 0.3526 - root_mean_squared_error: 0.5938 - mean_absolute_error: 0.4241 - mean_absolute_percentage_error: 1270.6472 - r2_score: 0.6444 - val_loss: 0.3686 - val_mean_squared_error: 0.3686 - val_root_mean_squared_error: 0.6071 - val_mean_absolute_error: 0.4437 - val_mean_absolute_percentage_error: 334.0159 - val_r2_score: 0.6477
# Epoch 28/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3511 - mean_squared_error: 0.3511 - root_mean_squared_error: 0.5925 - mean_absolute_error: 0.4227 - mean_absolute_percentage_error: 1148.0643 - r2_score: 0.6460 - val_loss: 0.3700 - val_mean_squared_error: 0.3700 - val_root_mean_squared_error: 0.6082 - val_mean_absolute_error: 0.4440 - val_mean_absolute_percentage_error: 351.2470 - val_r2_score: 0.6460
# Epoch 29/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3506 - mean_squared_error: 0.3506 - root_mean_squared_error: 0.5921 - mean_absolute_error: 0.4227 - mean_absolute_percentage_error: 1195.7357 - r2_score: 0.6465 - val_loss: 0.3663 - val_mean_squared_error: 0.3663 - val_root_mean_squared_error: 0.6052 - val_mean_absolute_error: 0.4424 - val_mean_absolute_percentage_error: 345.3177 - val_r2_score: 0.6492
# Epoch 30/50
# 44/44 [==============================] - 0s 4ms/step - loss: 0.3498 - mean_squared_error: 0.3498 - root_mean_squared_error: 0.5915 - mean_absolute_error: 0.4218 - mean_absolute_percentage_error: 1191.9302 - r2_score: 0.6473 - val_loss: 0.3675 - val_mean_squared_error: 0.3675 - val_root_mean_squared_error: 0.6062 - val_mean_absolute_error: 0.4418 - val_mean_absolute_percentage_error: 342.1555 - val_r2_score: 0.6484
# Epoch 31/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3492 - mean_squared_error: 0.3492 - root_mean_squared_error: 0.5909 - mean_absolute_error: 0.4215 - mean_absolute_percentage_error: 1221.5092 - r2_score: 0.6479 - val_loss: 0.3682 - val_mean_squared_error: 0.3682 - val_root_mean_squared_error: 0.6068 - val_mean_absolute_error: 0.4425 - val_mean_absolute_percentage_error: 357.3474 - val_r2_score: 0.6476
# Epoch 32/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3476 - mean_squared_error: 0.3476 - root_mean_squared_error: 0.5896 - mean_absolute_error: 0.4201 - mean_absolute_percentage_error: 1293.4991 - r2_score: 0.6495 - val_loss: 0.3676 - val_mean_squared_error: 0.3676 - val_root_mean_squared_error: 0.6063 - val_mean_absolute_error: 0.4409 - val_mean_absolute_percentage_error: 370.4690 - val_r2_score: 0.6481
# Epoch 33/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3474 - mean_squared_error: 0.3474 - root_mean_squared_error: 0.5894 - mean_absolute_error: 0.4202 - mean_absolute_percentage_error: 1139.0006 - r2_score: 0.6497 - val_loss: 0.3856 - val_mean_squared_error: 0.3856 - val_root_mean_squared_error: 0.6210 - val_mean_absolute_error: 0.4512 - val_mean_absolute_percentage_error: 365.9625 - val_r2_score: 0.6305
# Epoch 34/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3488 - mean_squared_error: 0.3488 - root_mean_squared_error: 0.5906 - mean_absolute_error: 0.4215 - mean_absolute_percentage_error: 1080.1770 - r2_score: 0.6482 - val_loss: 0.3621 - val_mean_squared_error: 0.3621 - val_root_mean_squared_error: 0.6017 - val_mean_absolute_error: 0.4381 - val_mean_absolute_percentage_error: 357.4906 - val_r2_score: 0.6526
# Epoch 35/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3395 - mean_squared_error: 0.3395 - root_mean_squared_error: 0.5826 - mean_absolute_error: 0.4160 - mean_absolute_percentage_error: 1122.7133 - r2_score: 0.6577 - val_loss: 0.3563 - val_mean_squared_error: 0.3563 - val_root_mean_squared_error: 0.5969 - val_mean_absolute_error: 0.4342 - val_mean_absolute_percentage_error: 370.1422 - val_r2_score: 0.6594
# Epoch 36/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3345 - mean_squared_error: 0.3345 - root_mean_squared_error: 0.5783 - mean_absolute_error: 0.4136 - mean_absolute_percentage_error: 1211.7094 - r2_score: 0.6627 - val_loss: 0.3500 - val_mean_squared_error: 0.3500 - val_root_mean_squared_error: 0.5916 - val_mean_absolute_error: 0.4300 - val_mean_absolute_percentage_error: 342.8646 - val_r2_score: 0.6656
# Epoch 37/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3308 - mean_squared_error: 0.3308 - root_mean_squared_error: 0.5752 - mean_absolute_error: 0.4106 - mean_absolute_percentage_error: 1065.7291 - r2_score: 0.6664 - val_loss: 0.3484 - val_mean_squared_error: 0.3484 - val_root_mean_squared_error: 0.5903 - val_mean_absolute_error: 0.4286 - val_mean_absolute_percentage_error: 361.7993 - val_r2_score: 0.6670
# Epoch 38/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3290 - mean_squared_error: 0.3290 - root_mean_squared_error: 0.5736 - mean_absolute_error: 0.4087 - mean_absolute_percentage_error: 1315.9840 - r2_score: 0.6682 - val_loss: 0.3457 - val_mean_squared_error: 0.3457 - val_root_mean_squared_error: 0.5880 - val_mean_absolute_error: 0.4263 - val_mean_absolute_percentage_error: 325.0993 - val_r2_score: 0.6693
# Epoch 39/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3273 - mean_squared_error: 0.3273 - root_mean_squared_error: 0.5721 - mean_absolute_error: 0.4078 - mean_absolute_percentage_error: 1046.6840 - r2_score: 0.6699 - val_loss: 0.3497 - val_mean_squared_error: 0.3497 - val_root_mean_squared_error: 0.5913 - val_mean_absolute_error: 0.4281 - val_mean_absolute_percentage_error: 353.5066 - val_r2_score: 0.6656
# Epoch 40/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3268 - mean_squared_error: 0.3268 - root_mean_squared_error: 0.5717 - mean_absolute_error: 0.4073 - mean_absolute_percentage_error: 1067.1451 - r2_score: 0.6705 - val_loss: 0.3472 - val_mean_squared_error: 0.3472 - val_root_mean_squared_error: 0.5893 - val_mean_absolute_error: 0.4281 - val_mean_absolute_percentage_error: 350.1482 - val_r2_score: 0.6678
# Epoch 41/50
# 44/44 [==============================] - 0s 7ms/step - loss: 0.3252 - mean_squared_error: 0.3252 - root_mean_squared_error: 0.5702 - mean_absolute_error: 0.4061 - mean_absolute_percentage_error: 1095.7719 - r2_score: 0.6721 - val_loss: 0.3458 - val_mean_squared_error: 0.3458 - val_root_mean_squared_error: 0.5881 - val_mean_absolute_error: 0.4255 - val_mean_absolute_percentage_error: 352.8716 - val_r2_score: 0.6700
# Epoch 42/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3254 - mean_squared_error: 0.3254 - root_mean_squared_error: 0.5705 - mean_absolute_error: 0.4065 - mean_absolute_percentage_error: 1040.8656 - r2_score: 0.6718 - val_loss: 0.3458 - val_mean_squared_error: 0.3458 - val_root_mean_squared_error: 0.5881 - val_mean_absolute_error: 0.4267 - val_mean_absolute_percentage_error: 349.3541 - val_r2_score: 0.6694
# Epoch 43/50
# 44/44 [==============================] - 0s 5ms/step - loss: 0.3237 - mean_squared_error: 0.3237 - root_mean_squared_error: 0.5689 - mean_absolute_error: 0.4052 - mean_absolute_percentage_error: 1076.8762 - r2_score: 0.6736 - val_loss: 0.3438 - val_mean_squared_error: 0.3438 - val_root_mean_squared_error: 0.5864 - val_mean_absolute_error: 0.4240 - val_mean_absolute_percentage_error: 346.8205 - val_r2_score: 0.6709
# Epoch 44/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3230 - mean_squared_error: 0.3230 - root_mean_squared_error: 0.5684 - mean_absolute_error: 0.4049 - mean_absolute_percentage_error: 1222.8643 - r2_score: 0.6743 - val_loss: 0.3419 - val_mean_squared_error: 0.3419 - val_root_mean_squared_error: 0.5848 - val_mean_absolute_error: 0.4233 - val_mean_absolute_percentage_error: 361.6768 - val_r2_score: 0.6730
# Epoch 45/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3230 - mean_squared_error: 0.3230 - root_mean_squared_error: 0.5683 - mean_absolute_error: 0.4047 - mean_absolute_percentage_error: 1258.8732 - r2_score: 0.6743 - val_loss: 0.3431 - val_mean_squared_error: 0.3431 - val_root_mean_squared_error: 0.5857 - val_mean_absolute_error: 0.4231 - val_mean_absolute_percentage_error: 354.6769 - val_r2_score: 0.6721
# Epoch 46/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3217 - mean_squared_error: 0.3217 - root_mean_squared_error: 0.5672 - mean_absolute_error: 0.4037 - mean_absolute_percentage_error: 1029.9370 - r2_score: 0.6756 - val_loss: 0.3427 - val_mean_squared_error: 0.3427 - val_root_mean_squared_error: 0.5854 - val_mean_absolute_error: 0.4238 - val_mean_absolute_percentage_error: 346.7292 - val_r2_score: 0.6724
# Epoch 47/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3210 - mean_squared_error: 0.3210 - root_mean_squared_error: 0.5666 - mean_absolute_error: 0.4033 - mean_absolute_percentage_error: 1176.5065 - r2_score: 0.6763 - val_loss: 0.3429 - val_mean_squared_error: 0.3429 - val_root_mean_squared_error: 0.5856 - val_mean_absolute_error: 0.4245 - val_mean_absolute_percentage_error: 364.4020 - val_r2_score: 0.6720
# Epoch 48/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3203 - mean_squared_error: 0.3203 - root_mean_squared_error: 0.5660 - mean_absolute_error: 0.4028 - mean_absolute_percentage_error: 1128.7419 - r2_score: 0.6770 - val_loss: 0.3414 - val_mean_squared_error: 0.3414 - val_root_mean_squared_error: 0.5843 - val_mean_absolute_error: 0.4223 - val_mean_absolute_percentage_error: 333.2863 - val_r2_score: 0.6737
# Epoch 49/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3203 - mean_squared_error: 0.3203 - root_mean_squared_error: 0.5660 - mean_absolute_error: 0.4027 - mean_absolute_percentage_error: 1099.5601 - r2_score: 0.6770 - val_loss: 0.3426 - val_mean_squared_error: 0.3426 - val_root_mean_squared_error: 0.5853 - val_mean_absolute_error: 0.4235 - val_mean_absolute_percentage_error: 355.1969 - val_r2_score: 0.6724
# Epoch 50/50
# 44/44 [==============================] - 0s 6ms/step - loss: 0.3196 - mean_squared_error: 0.3196 - root_mean_squared_error: 0.5654 - mean_absolute_error: 0.4021 - mean_absolute_percentage_error: 1036.5424 - r2_score: 0.6777 - val_loss: 0.3439 - val_mean_squared_error: 0.3439 - val_root_mean_squared_error: 0.5865 - val_mean_absolute_error: 0.4243 - val_mean_absolute_percentage_error: 345.4810 - val_r2_score: 0.6716

# %%
# visualize training and validation curves
plt.plot(history.history["mean_squared_error"], c='k')
plt.plot(history.history["val_mean_squared_error"], c='r')
plt.show()

# %%
plt.plot(history.history["mean_absolute_percentage_error"], c='k')
plt.plot(history.history["val_mean_absolute_percentage_error"], c='r')
plt.show()

# %%
# evaluation mode
y_pred = model.predict(X_test)
# Out:
# 21/21 [==============================] - 0s 2ms/step

# %%
# check prediction shape matches test data shape
y_pred.shape
# Out:
# (668, 1024)

# %%
y_test.shape
# Out:
# (668, 1024)

# %%
# visualize obs (x-axis) to nn predictions (y-axis)
plt.scatter(y_test, y_pred)
plt.show()

# %%
# evaluations (MSE)
mean_squared_error(y_test, y_pred)
# Out:
# 0.58079916

# %%
# to extract model layers, we can first print out model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 32)                32800
#
#  dense_7 (Dense)             (None, 8)                 264
#
#  dense_8 (Dense)             (None, 4)                 36
#
#  dense_9 (Dense)             (None, 8)                 40
#
#  dense_10 (Dense)            (None, 32)                288
#
#  dense_11 (Dense)            (None, 1024)              33792
#
# =================================================================
# Total params: 67220 (262.58 KB)
# Trainable params: 67220 (262.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# model layers are contained as a list
model.layers
# Out:
# [<keras.src.layers.core.dense.Dense at 0x786dbb4c4a00>,
#  <keras.src.layers.core.dense.Dense at 0x786db3272bc0>,
#  <keras.src.layers.core.dense.Dense at 0x786db3034490>,
#  <keras.src.layers.core.dense.Dense at 0x786db3035780>,
#  <keras.src.layers.core.dense.Dense at 0x786db3034580>,
#  <keras.src.layers.core.dense.Dense at 0x786db3035930>]

# %%
# lets select the first layer
model.layers[0].input
# Out:
# <KerasTensor: shape=(None, 1024) dtype=float32 (created by layer 'input_2')>

# %%
# and the bottleneck layer
model.layers[2].output
# Out:
# <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'dense_8')>

# %%
# we define the input layer to the ANN and the output of the bottleneck layer
bottleneck = keras.backend.function([model.layers[0].input],[model.layers[2].output])

# %%
# input test data into the bottleneck function
bottleneck_output = bottleneck(X_test)

# %%
# we can visualize what these two nodes in the bottleneck output
plt.scatter(bottleneck_output[0][:,0],bottleneck_output[0][:,1])
plt.show()

# %%
# we can visualize what these two nodes in the bottleneck output
plt.scatter(bottleneck_output[0][:,2],bottleneck_output[0][:,3])
plt.show()

# %%
# saving model
model.save('autoencodersample.keras')

# %%
# loading model
model2 = keras.models.load_model('autoencodersample.keras')

# %%
# inference with loaded model
ypred2 = model2.predict(X_test)
# Out:
# 21/21 [==============================] - 0s 2ms/step

# %% [markdown]
# We can use autoencoders for the task of anomaly detection. For anomaly detection, we would note instances where reconstruction error for an image is higher, indicating that the sample was likely not similar to those in the training set distribution.

# %%
# for get the mean absolute error between actual and reconstruction/prediction
prediction_loss = keras.losses.mae(ypred2, X_test)

# for check the prediction loss threshold for 2% of outliers
loss_threshold = np.percentile(prediction_loss, 98)

print(f'The prediction loss threshold for 2% of outliers is {loss_threshold:.2f}')
# for visualize the threshold
plt.hist(prediction_loss, bins=30, alpha=0.8)
plt.axvline(x=loss_threshold, color='orange')
plt.show()
# Out:
# The prediction loss threshold for 2% of outliers is 0.97

# %%
# same as above but for inverse transformed data
# for get the mean absolute error between actual and reconstruction/prediction
prediction_loss = keras.losses.mae(
    scaler.inverse_transform(ypred2),
    scaler.inverse_transform(X_test)
    )

# for check the prediction loss threshold for 2% of outliers
loss_threshold = np.percentile(prediction_loss, 98)

print(f'The prediction loss threshold for 2% of outliers is {loss_threshold:.2f}')
# for visualize the threshold
plt.hist(prediction_loss, bins=30, alpha=0.8)
plt.axvline(x=loss_threshold, color='orange')
plt.show()
# Out:
# The prediction loss threshold for 2% of outliers is 18.60

# %% [markdown]
# ## CNN Autoencoder

# %%
def z_score(da):
    """
    Compute z-score for training data.
    Normalizing data for ML model training.
    Args:
        da (array): Array of training variable.
    """
    return (da - np.mean(da)) / np.std(da)

def z_score_testing(da, testdata):
    """
    Compute z-score for testing data.
    Args:
        da (array): Array of training variable.
    """
    return (testdata - np.mean(da)) / np.std(da)

# %%
# reshape data to be samples, features
features_data = ds['dbz_grid'].values
print(features_data.shape)
# Out:
# (2224, 32, 32)

# %%
X_train, X_test, y_train, y_test = features_data[:1800], features_data[1800:], features_data[:1800], features_data[1800:]

# %%
X_test = z_score_testing(X_train, X_test) # input
y_test = z_score_testing(y_train, y_test) # label

X_train = z_score(X_train) # input
y_train = z_score(y_train) # label

# %%
# check shapes
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1800, 32, 32) (424, 32, 32) (1800, 32, 32) (424, 32, 32)

# %%
model = keras.Sequential()

# input
model.add(keras.Input(shape=(32, 32, 1)))  # 32x32 images

# encoder
# hidden layers
model.add(layers.Conv2D(16, 3, strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(2))

model.add(layers.Conv2D(8, 3, strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(2))

model.add(layers.Conv2D(4, 3, strides=1, padding="same", activation="relu"))
model.add(layers.MaxPooling2D(2))

# decoder
model.add(layers.Conv2D(4, 3, strides=1, padding="same", activation="relu"))
model.add(layers.UpSampling2D(2))

model.add(layers.Conv2D(8, 3, strides=1, padding="same", activation="relu"))
model.add(layers.UpSampling2D(2))

model.add(layers.Conv2D(16, 3, strides=1, padding="same", activation="relu"))
model.add(layers.UpSampling2D(2))

# Finally, we add last layer
model.add(layers.Conv2D(1, (3, 3), activation='linear', padding='same'))

# print model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 8)         1160
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 8)           0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 4)           292
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 4)           0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 4)           148
#
#  up_sampling2d (UpSampling2  (None, 8, 8, 4)           0
#  D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 8)           296
#
#  up_sampling2d_1 (UpSamplin  (None, 16, 16, 8)         0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 16)        1168
#
#  up_sampling2d_2 (UpSamplin  (None, 32, 32, 16)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 1)         145
#
# =================================================================
# Total params: 3369 (13.16 KB)
# Trainable params: 3369 (13.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
METRICS = [
    keras.metrics.MeanSquaredError(name='mean_squared_error'),
    keras.metrics.RootMeanSquaredError(name='root_mean_squared_error'),
]

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss="mean_squared_error",
    metrics=METRICS
)

BATCH_SIZE = 32
EPOCHS = 10

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,
    shuffle=True,
)
# Out:
# Epoch 1/10
# 51/51 [==============================] - 5s 51ms/step - loss: 0.6572 - mean_squared_error: 0.6572 - root_mean_squared_error: 0.8107 - val_loss: 0.5431 - val_mean_squared_error: 0.5431 - val_root_mean_squared_error: 0.7370
# Epoch 2/10
# 51/51 [==============================] - 2s 46ms/step - loss: 0.3308 - mean_squared_error: 0.3308 - root_mean_squared_error: 0.5752 - val_loss: 0.3983 - val_mean_squared_error: 0.3983 - val_root_mean_squared_error: 0.6311
# Epoch 3/10
# 51/51 [==============================] - 2s 46ms/step - loss: 0.2610 - mean_squared_error: 0.2610 - root_mean_squared_error: 0.5109 - val_loss: 0.3565 - val_mean_squared_error: 0.3565 - val_root_mean_squared_error: 0.5971
# Epoch 4/10
# 51/51 [==============================] - 4s 69ms/step - loss: 0.2315 - mean_squared_error: 0.2315 - root_mean_squared_error: 0.4811 - val_loss: 0.3303 - val_mean_squared_error: 0.3303 - val_root_mean_squared_error: 0.5747
# Epoch 5/10
# 51/51 [==============================] - 2s 44ms/step - loss: 0.2160 - mean_squared_error: 0.2160 - root_mean_squared_error: 0.4648 - val_loss: 0.3161 - val_mean_squared_error: 0.3161 - val_root_mean_squared_error: 0.5622
# Epoch 6/10
# 51/51 [==============================] - 2s 42ms/step - loss: 0.2056 - mean_squared_error: 0.2056 - root_mean_squared_error: 0.4535 - val_loss: 0.3064 - val_mean_squared_error: 0.3064 - val_root_mean_squared_error: 0.5536
# Epoch 7/10
# 51/51 [==============================] - 2s 45ms/step - loss: 0.1971 - mean_squared_error: 0.1971 - root_mean_squared_error: 0.4440 - val_loss: 0.2991 - val_mean_squared_error: 0.2991 - val_root_mean_squared_error: 0.5469
# Epoch 8/10
# 51/51 [==============================] - 3s 50ms/step - loss: 0.1921 - mean_squared_error: 0.1921 - root_mean_squared_error: 0.4383 - val_loss: 0.2932 - val_mean_squared_error: 0.2932 - val_root_mean_squared_error: 0.5415
# Epoch 9/10
# 51/51 [==============================] - 4s 69ms/step - loss: 0.1850 - mean_squared_error: 0.1850 - root_mean_squared_error: 0.4301 - val_loss: 0.2843 - val_mean_squared_error: 0.2843 - val_root_mean_squared_error: 0.5332
# Epoch 10/10
# 51/51 [==============================] - 2s 46ms/step - loss: 0.1790 - mean_squared_error: 0.1790 - root_mean_squared_error: 0.4231 - val_loss: 0.2846 - val_mean_squared_error: 0.2846 - val_root_mean_squared_error: 0.5335

# %%
plt.plot(history.history["mean_squared_error"], c='k')
plt.plot(history.history["val_mean_squared_error"], c='r')
plt.show()

# %%
# saving model
model.save('autoencodercnn.keras')

# loading model
model2 = keras.models.load_model('autoencodercnn.keras')

# %%
# inference with loaded model
ypred2 = model2.predict(X_test)
# Out:
# 14/14 [==============================] - 0s 12ms/step

# %%
print(X_test.shape, ypred2[:,:,:,0].shape)
# Out:
# (424, 32, 32) (424, 32, 32)

# %%
# evaluations
plt.scatter(np.ndarray.flatten(y_test), np.ndarray.flatten(ypred2[:,:,:,0]))
plt.show()

# %%
# evaluations
sample_indx = 10

plt.imshow(y_test[sample_indx,:,:], vmin=-1, vmax=1)
plt.show()

plt.imshow(ypred2[sample_indx,:,:,0], vmin=-1, vmax=1)
plt.show()

plt.imshow(ypred2[sample_indx,:,:,0] - y_test[sample_indx,:,:], cmap='seismic')
plt.show()

# %%
# evaluations (MSE)
mean_squared_error(np.ndarray.flatten(y_test), np.ndarray.flatten(ypred2[:,:,:,0]))
# Out:
# 0.37860158

# %% [markdown]
# ## CNN Autoencoder Noise Removal

# %%
def noise(array):
    """Adds random noise to each image in the supplied array."""
    noise_factor = 0.4
    noisy_array = array + noise_factor * np.random.normal(
        loc=0.0, scale=1.0, size=array.shape
    )
    return noisy_array

# %%
# reshape data to be samples, features
features_data = ds['dbz_grid'].values
print(features_data.shape)

X_train, X_test, y_train, y_test = features_data[:1800], features_data[1800:], features_data[:1800], features_data[1800:]

X_test = z_score_testing(X_train, X_test) # input
y_test = z_score_testing(y_train, y_test) # label

X_train = z_score(X_train) # input
y_train = z_score(y_train) # label

# check shapes
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (2224, 32, 32)
# (1800, 32, 32) (424, 32, 32) (1800, 32, 32) (424, 32, 32)

# %%
# Create a copy of the data with added noise
noisy_train_data = noise(X_train)
noisy_test_data = noise(X_test)

# %%
plt.imshow(noisy_train_data[0,:,:], vmin=-1, vmax=1)
plt.show()

plt.imshow(X_train[0,:,:], vmin=-1, vmax=1)
plt.show()

# %%
model_transfer = keras.models.load_model('autoencodercnn.keras')

# %%
history = model_transfer.fit(
    x=noisy_train_data,
    y=y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_split=0.1,
    shuffle=True,
)
# Out:
# Epoch 1/10
# 51/51 [==============================] - 7s 61ms/step - loss: 0.1805 - mean_squared_error: 0.1805 - root_mean_squared_error: 0.4249 - val_loss: 0.2740 - val_mean_squared_error: 0.2740 - val_root_mean_squared_error: 0.5235
# Epoch 2/10
# 51/51 [==============================] - 2s 42ms/step - loss: 0.1737 - mean_squared_error: 0.1737 - root_mean_squared_error: 0.4168 - val_loss: 0.2674 - val_mean_squared_error: 0.2674 - val_root_mean_squared_error: 0.5171
# Epoch 3/10
# 51/51 [==============================] - 2s 42ms/step - loss: 0.1685 - mean_squared_error: 0.1685 - root_mean_squared_error: 0.4105 - val_loss: 0.2619 - val_mean_squared_error: 0.2619 - val_root_mean_squared_error: 0.5118
# Epoch 4/10
# 51/51 [==============================] - 2s 45ms/step - loss: 0.1649 - mean_squared_error: 0.1649 - root_mean_squared_error: 0.4061 - val_loss: 0.2554 - val_mean_squared_error: 0.2554 - val_root_mean_squared_error: 0.5053
# Epoch 5/10
# 51/51 [==============================] - 3s 67ms/step - loss: 0.1608 - mean_squared_error: 0.1608 - root_mean_squared_error: 0.4010 - val_loss: 0.2516 - val_mean_squared_error: 0.2516 - val_root_mean_squared_error: 0.5016
# Epoch 6/10
# 51/51 [==============================] - 2s 46ms/step - loss: 0.1572 - mean_squared_error: 0.1572 - root_mean_squared_error: 0.3964 - val_loss: 0.2451 - val_mean_squared_error: 0.2451 - val_root_mean_squared_error: 0.4950
# Epoch 7/10
# 51/51 [==============================] - 2s 44ms/step - loss: 0.1537 - mean_squared_error: 0.1537 - root_mean_squared_error: 0.3921 - val_loss: 0.2417 - val_mean_squared_error: 0.2417 - val_root_mean_squared_error: 0.4916
# Epoch 8/10
# 51/51 [==============================] - 2s 41ms/step - loss: 0.1514 - mean_squared_error: 0.1514 - root_mean_squared_error: 0.3891 - val_loss: 0.2392 - val_mean_squared_error: 0.2392 - val_root_mean_squared_error: 0.4891
# Epoch 9/10
# 51/51 [==============================] - 2s 40ms/step - loss: 0.1487 - mean_squared_error: 0.1487 - root_mean_squared_error: 0.3857 - val_loss: 0.2352 - val_mean_squared_error: 0.2352 - val_root_mean_squared_error: 0.4850
# Epoch 10/10
# 51/51 [==============================] - 3s 58ms/step - loss: 0.1470 - mean_squared_error: 0.1470 - root_mean_squared_error: 0.3834 - val_loss: 0.2326 - val_mean_squared_error: 0.2326 - val_root_mean_squared_error: 0.4823

# %%
plt.plot(history.history["mean_squared_error"], c='k')
plt.plot(history.history["val_mean_squared_error"], c='r')
plt.show()

# %%
# inference with model
ypred = model.predict(noisy_test_data)
# Out:
# 14/14 [==============================] - 0s 21ms/step

# %%
# evaluations
sample_indx = 10

plt.imshow(noisy_test_data[sample_indx, :, :])
plt.show()

plt.imshow(y_test[sample_indx,:,:])
plt.show()

plt.imshow(ypred[sample_indx,:,:,0])
plt.show()

plt.imshow(ypred[sample_indx,:,:,0] - y_test[sample_indx,:,:], cmap='seismic')
plt.show()
